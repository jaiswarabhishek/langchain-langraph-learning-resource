# %%
## Data Loading

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("cybersec.pdf")

pdf_document = loader.load()

print(pdf_document)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'PyPDF', 'creationdate': '2019-12-17T19:23:53+05:30', 'authoritativedomain[1]': 'sciencedirect.com', 'authoritativedomain[2]': 'elsevier.com', 'elsevierwebpdfspecifications': '6.5', 'moddate': '2019-12-23T15:28:43+05:30', 'doi': '10.1016/j.ifacol.2019.11.313', 'robots': 'noindex', 'source': 'cybersec.pdf', 'total_pages': 6, 'page': 0, 'page_label': '928'}, page_content='IFAC PapersOnLine 52-13 (2019) 928–933\nScienceDirect\nAvailable online at www.sciencedirect.com\n2405-8963 © 2019, IFAC (International Federation of Automatic Control) Hosting by Elsevier Ltd. All rights reserved.\nPeer review under responsibility of International Federation of Automatic Control.\n10.1016/j.ifacol.2019.11.313\n© 2019, IFAC (International Federation of Automatic Control) Hosting by Elsevier Ltd. All rights reserved.\n10.1016/j.ifacol.2019.11.313 2405-8963\n   \nA Clustering Method of Asset Cybersecurity Classification \n \nVitaly G. Promyslov*, \n Kirill V. Semenkov*, \nAlexander S. Shumov* \n\uf020\n*V.A. Trapeznikov Institute of Control Sciences, Russian Academy of Science, \n65 Profsoyuznaya, Moscow 117997, Russia \n(Tel: +7-495-334-25-22; e-mail: v1925@mail.ru) \nAbstract: A formal method for asset classifying by cyber security is provided. The problem is solved in \nthe frame of a clustering problem. The data structure and content are specified. A classification algorithm \nfor systems with arbitrary number of subsystems is provided. Copyright © 2019 IFAC \nKeywords: cyber security, formal methods, asset cla ssification, clustering, “take-grant” model, \nhierarchical systems. \n\uf020\n1. INTRODUCTION \nThe security of the society and the state depends significantly \non the security of the backbone infrastructure facilities \nincluding (IEC, 2016) nuclear power plants (NPP). The \nproblem of securing I&C (instrumentation and control) \nsystems of NPPs is overall and related to industrial (energy, \nnuclear and radiological, functional) safety precautions. The \nsafe and efficient operation of modern NPPs is ensured by \ndigital control systems that require appropriate protection \nagainst unauthorized actions, fo r example, against computer \nattacks, which belongs to the area of information and cyber \nsecurity (see e.g. Mengazetdinov et al. (2005)). \nThe solution of the problem of cyber security ensuring is \nclosely related to the tasks of finding critical assets in the \nprotected system and assigning the protection measures to \nthese assets as required by IEC 62645 (2014).  \nTo solve the problems it is necessary to answer some \nquestions. \n1. Which protection measures should be assigned to the \ncritical assets to ensure the safety of the whole object? \n2. How to make the protection efficient, minimizing the set of \napplied protection measures for the assets? \n3. How to estimate a degree of vulnerability for any asset? \nThese questions are the crucial ones in the problem of cyber \nsecurity. They are addressed in a number of documents and \nresearch papers. Among the complex papers we may mention \nthe ones developed by the In ternational Electrotechnical \nCommission (IEC) and the International Atomic Energy \nAgency (IAEA) (see IAIA 2011, IEC 2014, 2016), ISO/IEC \n27000 standard family, papers by Promyslov and Poletykin \n(2016) and Harchenko et al. (2013) in regard to common \nprinciples of ensuring the security of digital control systems. \nThe following practice for ensuri ng the security of complex \ncomputer-based systems has been  established: to build the \nsecurity architecture using princi ples of graded approach and \ndefense in depth, when the cyber security levels are assigned \nto the assets in conformity with the criticality of the asset for \nthe general security (IEC, 2016; FSTEK Russia, 2014) basing \non risk assessment. The protection degree for every asset \nmust conform to the assigned level of cyber security. The \nsuitable barriers  ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=0)
texts = text_splitter.split_documents(pdf_document)

print(texts[0])
print(texts[1])
# Out:
# page_content='IFAC PapersOnLine 52-13 (2019) 928–933
# ScienceDirect
# Available online at www.sciencedirect.com' metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'PyPDF', 'creationdate': '2019-12-17T19:23:53+05:30', 'authoritativedomain[1]': 'sciencedirect.com', 'authoritativedomain[2]': 'elsevier.com', 'elsevierwebpdfspecifications': '6.5', 'moddate': '2019-12-23T15:28:43+05:30', 'doi': '10.1016/j.ifacol.2019.11.313', 'robots': 'noindex', 'source': 'cybersec.pdf', 'total_pages': 6, 'page': 0, 'page_label': '928'}
# page_content='2405-8963 © 2019, IFAC (International Federation of Automatic Control) Hosting by Elsevier Ltd. All' metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'PyPDF', 'creationdate': '2019-12-17T19:23:53+05:30', 'authoritativedomain[1]': 'sciencedirect.com', 'authoritativedomain[2]': 'elsevier.com', 'elsevierwebpdfspecifications': '6.5', 'moddate': '2019-12-23T15:28:43+05:30', 'doi': '10.1016/j.ifacol.2019.11.313', 'robots': 'noindex', 'source': 'cybersec.pdf', 'total_pages': 6, 'page': 0, 'page_label': '928'}

# %%
from langchain_text_splitters import (
    Language,
    RecursiveCharacterTextSplitter,
)

[e.value for e in Language]
# Out:
# ['cpp',
#  'go',
#  'java',
#  'kotlin',
#  'js',
#  'ts',
#  'php',
#  'proto',
#  'python',
#  'r',
#  'rst',
#  'ruby',
#  'rust',
#  'scala',
#  'swift',
#  'markdown',
#  'latex',
#  'html',
#  'sol',
#  'csharp',
#  'cobol',
#  'c',
#  'lua',
#  'perl',
#  'haskell',
#  'elixir',
#  'powershell',
#  'visualbasic6']

# %%
PYTHON_CODE = """
def hello_world():
    print("Hello, World!")

# Call the function
hello_world()
"""
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, chunk_size=50, chunk_overlap=0
)
python_docs = python_splitter.create_documents([PYTHON_CODE])
python_docs
# Out:
# [Document(metadata={}, page_content='def hello_world():\n    print("Hello, World!")'),
#  Document(metadata={}, page_content='# Call the function\nhello_world()')]
